# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

# %% [markdown]
# # Random linear data

# %%
x = sorted(np.random.randint(100, size=100))
y = sorted(np.random.randint(100, size=100))

# %%
fig, ax = plt.subplots()
ax.scatter(x, y, c='black')

# %% [markdown]
# When we finish our line should look very close to this

# %%
plt.plot(x, y, 'o')
m, b = np.polyfit(x, y, 1)
plt.plot(x, [m*i + b for i in x])

# %%
# Choose a random line to start your model (will most likely be trash)
line = .5 * x + 2 # Where .5 is slope and 2 is intercept
